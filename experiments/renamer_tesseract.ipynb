# %% [markdown]
# # File Renamer (Tesseract)
# Renames files according to the image timestamp.

# %%
import cv2
import os

import numpy as np
from pytesseract import image_to_string
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# def get_text_(filename: str):
# 	# Read image
# 	img = cv2.imread(filename)
# 	img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# 	txt = image_to_string(img_rgb)
# 	return txt

# %%
def get_text(filename: str, therm: bool):
	# Read image
	img: np.ndarray = cv2.imread(filename)
	# Crop
	img = img[20:100, 20:620] if therm else img[40:140, 40:820]
	# Threshold
	HSV_img = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
	h,s,v = cv2.split(HSV_img)
	v = cv2.GaussianBlur(v, (1,1), 0)
	thresh = cv2.threshold(v, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
	kernel = cv2.getStructuringElement(cv2.MORPH_RECT, ksize=(1, 1))
	thresh = cv2.dilate(thresh, kernel)
	plt.imshow(thresh, 'gray')
	plt.show()
	# Return text
	txt = image_to_string(thresh)
	return txt

# %%
# path = 'data/pictures/clean thermal/'
# for f in os.listdir(path):
# 	if f[-4:] == '.jpg':
# 		print(path + f)
# 		text = get_text(filename=path + f, therm=True)
# 		text = text.replace(':', '')
# 		text = text.replace(' ', '_')
# 		text.rstrip()
# 		print(text)
# 		os.rename(path + f, path + text + '.jpg')

# %%
path = 'data/pictures/05.08.22/therm/'
for f in os.listdir(path):
	if f[-4:] == '.jpg':
		print(f)
		text = get_text(filename=path + f, therm=True)
		print(text)
		os.rename(path + f, path + text.replace(' ', '_') + '.jpg')
# Out:
# O8-O05-202F_Fri_03:34:00
# —E—~_+__§
# .jpg
# O8-O05-202F Fri 03:34:00
# —E—~ +  §
#
# 08-06-2022_Fri_Sospcecva
# .jpg
# 08-06-2022 Fri Sospcecva
#
# ON?_03:31:29
# ——————_“air
# .jpg
# ON? 03:31:29
# —————— “air
#
# 08-05-2022_Fri_OFT25:0
# .jpg
# 08-05-2022 Fri OFT25:0
#
# a1_SaGPORZ_Fri_03:32:16
# .jpg
# a1 SaGPORZ Fri 03:32:16
#
# 06-05-2022_Fri_03:34:00
# ———E———E_|
# .jpg
# 06-05-2022 Fri_03:34:00
# ———E———E |
#
# 23-05-2022_Fr_iS_:_39_:_RY
# .jpg
# 23-05-2022 Fr iS : 39 : RY
#
# 08-05-2022_Fri_03:20:
# .jpg
# 08-05-2022 Fri 03:20:
#
# Bemyeeco22_Fri_03:35:
# .jpg
# Bemyeeco22 Fri 03:35:
#
# 08-05-2022_Fri_06:08:45
# —-
# .jpg
# 08-05-2022 Fri 06:08:45
# —-
#
# 06-05-2022_Fri_03:21:36
# .jpg
# 06-05-2022 Fri 03:21:36
#
# 28-05_ROPE_FEY_03:34:29
#
# .jpg
# 28-05 ROPE FEY 03:34:29
#
#
# 08-05-2022_Fri_03:29:45
# EE_—E_ll_ttm
# .jpg
# 08-05-2022 Fri 03:29:45
# EE —E ll ttm
#
# O8-05-2022_Fri_03:34:47
# .jpg
# O8-05-2022 Fri 03:34:47
#
# f_022_Fri_03730:58
# .jpg
# ...
